# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("EDA.csv")
df.head(10)
# Out:
#         id      date                  c1 c2         country  \
# 0  1381034  20180418            helpdesk  a  United Kingdom
# 1   471386  20180515                   c  a   United States
# 2  1867433  20190508                   c  a  United Kingdom
# 3  2713558  20190325  search-philippines  a     Philippines
# 4  1545847  20190503                   o  a           India
# 5   929805  20180403                 (n)  a          Israel
# 6   884749  20180217            referral  a      Montenegro
# 7   258520  20190130                   o  a           India
# 8  1893663  20190612                 (n)  a          Canada
# 9  1476272  20180724                   o  b       Australia
#
#                      c4         city                 c6  \
# 0              training  Stalybridge           training
# 1  (automatic matching)  Santa Clara             google
# 2              usdlt15k       London             google
# 3           zendesk.com       Manila     google-adwords
# ...

# %% [markdown]
# c1=traficsource
# c6=source
# c7=medium

# %%
df.describe()
# Out:
#                  id          date            o1            n1            n2  \
# count  2.351118e+06  2.351118e+06  2.351118e+06  2.351118e+06  2.351118e+06
# mean   1.469592e+06  2.018391e+07  3.832843e+00  7.479608e-01  2.927694e+00
# std    8.483559e+05  4.586940e+03  1.877755e+01  1.134143e+00  6.505663e+00
# min    2.000000e+00  2.018010e+07  1.000000e+00  0.000000e+00  1.000000e+00
# 25%    7.345795e+05  2.018052e+07  1.000000e+00  0.000000e+00  1.000000e+00
# 50%    1.469616e+06  2.018093e+07  1.000000e+00  1.000000e+00  2.000000e+00
# 75%    2.204582e+06  2.019022e+07  2.000000e+00  1.000000e+00  3.000000e+00
# max    2.938897e+06  2.019062e+07  5.328000e+03  1.245000e+03  1.350000e+03
#
#                  b1            n3            n4            n5          hour  \
# count  2.351118e+06  2.351118e+06  2.351118e+06  2.351118e+06  2.334236e+06
# mean   7.801599e-01  2.119779e+00  7.678921e+01  1.158218e+00  9.585255e+00
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d').dt.strftime('%d/%m/%Y')

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351118 entries, 0 to 2351117
# Data columns (total 46 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   id       int64
#  1   date     object
#  2   c1       object
#  3   c2       object
#  4   country  object
#  5   c4       object
#  6   city     object
#  7   c6       object
#  8   c7       object
#  9   o1       int64
#  10  region   object
#  11  n1       float64
#  12  n2       float64
#  13  b1       float64
#  14  n3       float64
#  15  n4       float64
#  16  n5       float64
#  17  c9       object
#  18  hour     float64
#  19  b2       float64
#  20  b3       float64
#  21  b4       float64
#  22  b5       float64
#  23  b6       float64
#  24  b7       float64
#  25  b8       float64
#  26  b9       float64
#  27  b10      float64
#  28  b11      float64
#  29  b12      float64
#  30  n6       float64
#  31  n7       float64
#  32  n8       float64
#  33  n9       float64
#  34  n10      float64
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# id               0
# n5               0
# n4               0
# n3               0
# b1               0
# n2               0
# n1               0
# region           0
# o1               0
# b17              0
# c6               0
# city             0
# c4               0
# country          0
# c2               0
# c1               0
# date             0
# c7               0
# b12          16882
# b11          16882
# b9           16882
# b8           16882
# b7           16882
# b10          16882
# b5           16882
# b4           16882
# b3           16882
# b2           16882
# hour         16882
# b6           16882
# n15          33034
# n7           35385
# n9           35758
# n13          55614
# n6           55837
# n11          66816
# n12          87425
# n10          92265
# n8          107079
# n14         115840
# c9         1094714
# n16        1122744
# b13        2176877
# b14        2176877
# b15        2176877
# b16        2176877
# dtype: int64

# %%
print(df.groupby(['c1','c2','c4','c6','c7','c9']).size())
# Out:
# c1                                c2  c4                               c6        c7                           c9
# (n)                               a   (Remarketing/Content targeting)  google    (not set)                    apps.somethingdesk.com           1
#                                                                                                               googleads.g.doubleclick.net      1
#                                                                                  Remarketing-UAE,Saudi-Disp   support.somethingdesk.com        1
#                                                                                  Remarketing-US-Disp          threattrack.somethingdesk.com    1
#                                                                                  Remarketing-US-Disp(Others)  googleads.g.doubleclick.net      1
#                                                                                                                                               ..
# ...

# %%
df[['n1','n2','n3','n4','n5','n6','n7','n8','n9','n10','n11','n16']].max()
# Out:
# n1      1245.000
# n2      1350.000
# n3      1350.000
# n4     59600.000
# n5      1262.000
# n6     28736.372
# n7     16690.691
# n8      9341.402
# n9      9744.719
# n10    26523.516
# n11     7439.036
# n16    50457.105
# dtype: float64

# %% [markdown]
# c1:
# c2: categorical(maybe a=web,b=mob,c=tab)
# c4:
# c6: channel grouping
# c7:
# c9: session source

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=df['country'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9320\3586338884.py in <module>
#       1 sns.set(rc={'figure.figsize':(15,5)})
# ----> 2 sns.barplot(data=df['country'])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
sns.scatterplot(data=df,x='n1',y='b17')
# Out:
# <AxesSubplot:xlabel='n1', ylabel='b17'>

# %%
df['n16'].corr(df['b17'])
# Out:
# 0.04770173708369633

# %%
sns.pairplot(data=df[['n16','b13','b14','b15','b16','b17']])
